# %% [markdown]
# # Statistics for Data Science with Python Project - by Heramb Devarajan

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import statsmodels.api as sm

# %%
boston_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
boston_df=pd.read_csv(boston_url)

# %%
boston_df.head(10)
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0
# 5           5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0
# 6           6  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0
# 7           7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0
# 8           8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0
# 9           9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0
#
#      TAX  PTRATIO  LSTAT  MEDV
# 0  296.0     15.3   4.98  24.0
# 1  242.0     17.8   9.14  21.6
# 2  242.0     17.8   4.03  34.7
# ...

# %%
boston_df.describe()
# Out:
#        Unnamed: 0        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   252.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      0.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    126.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    252.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    378.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    505.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %% [markdown]
# ### Become familiar with the dataset

# %% [markdown]
# The following describes the dataset variables:
#
# ·      CRIM - per capita crime rate by town
#
# ·      ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
#
# ·      INDUS - proportion of non-retail business acres per town.
#
# ·      CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
#
# ·      NOX - nitric oxides concentration (parts per 10 million)
#
# ·      RM - average number of rooms per dwelling
#
# ·      AGE - proportion of owner-occupied units built prior to 1940
#
# ·      DIS - weighted distances to five Boston employment centres
#
# ·      RAD - index of accessibility to radial highways
#
# ·      TAX - full-value property-tax rate per $10,000
#
# ·      PTRATIO - pupil-teacher ratio by town
#
# ·      LSTAT - % lower status of the population
#
# ·      MEDV - Median value of owner-occupied homes in $1000's

# %% [markdown]
# ### Task 1) For the "Median value of owner-occupied homes" provide a Box Plot

# %%
box_plot=sns.boxplot(y='MEDV',data=boston_df)
box_plot.set_title('Owner-occupied homes')
# Out:
# Text(0.5, 1.0, 'Owner-occupied homes')

# %% [markdown]
# The boxplot above shows how the value of owner-occupied homes are distributed

# %% [markdown]
# ### Task 2) Provide a  bar plot for the Charles river variable

# %%
bar_plot=sns.countplot(x="CHAS",data=boston_df)
bar_plot.set_title("Charles River Data")
# Out:
# Text(0.5, 1.0, 'Charles River Data')

# %% [markdown]
# The histogram shows that the majority of the areas are not near the Charles River

# %% [markdown]
# ### Task 3) Provide a boxplot for the MEDV variable vs the AGE variable.
# ### (Discretize the age variable into three groups of 35 years and younger, between 35 and 70 years and 70 years and older)

# %%
boston_df.loc[boston_df['AGE']<=35,'Age_Group']='35 years and younger'
boston_df.loc[(boston_df['AGE']>35) & (boston_df['AGE']<70),'Age_Group']='between 35 and 70 years'
boston_df.loc[boston_df['AGE']>=70,'Age_Group']='70 years and older'

# %%
box_plot2= sns.boxplot(x='MEDV',y='Age_Group',data=boston_df)
box_plot2.set_title(' Valur of owner occupied house by age')
# Out:
# Text(0.5, 1.0, ' Valur of owner occupied house by age')

# %% [markdown]
# The boxplot above shows that on average the value of owner occupied homes is higher when the Age is lower

# %% [markdown]
# ### Task 4) Provide a scatter plot to show the relationship between Nitric oxide concentrations and the proportion of
# ### non-retail business acres per town. What can you say about the relationship?

# %%
scatter_plot1=sns.scatterplot(x='NOX',y='INDUS',data=boston_df)

# %% [markdown]
# The scatterplot shows the relationship between Nitric oxide concentrations and the proportion of
# non-retail business acres per town. We can say that they are directly proportional.

# %% [markdown]
# ### Task 5) Create a histogram for the pupil to teacher ratio variable

# %%
hist1=sns.histplot(x='PTRATIO',data=boston_df)

# %% [markdown]
# The above histogram shows the pupil to teacher ratio variable by town

# %% [markdown]
# ## Tests for Statistics

# %% [markdown]
# ### Task 6) Is there a significant difference in median value of houses bounded by the Charles river or not? (T-test for independent samples)

# %% [markdown]
# Hypothesis:
#
# Null hypothesis: There is no significant difference in median value of houses bounded by the Charles river.
#
# Alternative  hypothesis: There is significant difference in median value of houses bounded by the Charles river.

# %%
boston_df.loc[(boston_df['CHAS'] == 0), 'CHAS_T'] = 'FAR'
boston_df.loc[(boston_df['CHAS'] == 1), 'CHAS_T'] = 'NEAR'
boston_df.head()
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
#
#      TAX  PTRATIO  LSTAT  MEDV                Age_Group CHAS_T
# 0  296.0     15.3   4.98  24.0  between 35 and 70 years    FAR
# 1  242.0     17.8   9.14  21.6       70 years and older    FAR
# 2  242.0     17.8   4.03  34.7  between 35 and 70 years    FAR
# 3  222.0     18.7   2.94  33.4  between 35 and 70 years    FAR
# 4  222.0     18.7   5.33  36.2  between 35 and 70 years    FAR

# %%
scipy.stats.ttest_ind(boston_df[boston_df['CHAS_T'] == 'FAR']['MEDV'], 
                      boston_df[boston_df['CHAS_T'] == 'NEAR']['MEDV'], equal_var = True)
# Out:
# Ttest_indResult(statistic=-3.996437466090509, pvalue=7.390623170519905e-05)

# %% [markdown]
# Given the p-value is less than 0.05, we reject the Null Hypothesis, meaning there is a statistical difference in
# median value between houses near the Charles River and houses far away.

# %% [markdown]
# ### Task 7) Is there a difference in Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE)? (ANOVA)

# %% [markdown]
# Hypothesis:
#
# Null hypothesis: there is no difference in Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE).
#
# Alternative hypothesis: there is a difference in Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE).

# %%
from statsmodels.formula.api import ols
lm = ols('MEDV ~ AGE', data = boston_df).fit()
table = sm.stats.anova_lm(lm)
print(table)
# Out:
#              df        sum_sq      mean_sq          F        PR(>F)
# AGE         1.0   6069.761065  6069.761065  83.477459  1.569982e-18
# Residual  504.0  36646.534350    72.711378        NaN           NaN

# %% [markdown]
# Given the p-value is less than 0.05, we reject the Null Hypothesis, meaning there is a statistical difference in median value of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE).

# %% [markdown]
# ### Task 8) Can we conclude that there is no relationship between Nitric oxide concentrations and proportion of non-retail business acres per town? (Pearson Correlation)

# %% [markdown]
# Hypothesis:
#
# Null hypothesis: There is no relationship between Nitric oxide concentrations and proportion of non-retail business acres per town.
#
# Alternative hypothesis: There is a relationship between Nitric oxide concentrations and proportion of non-retail business acres per town.

# %%
scipy.stats.pearsonr(boston_df['NOX'],boston_df['INDUS'])
# Out:
# (0.7636514469209151, 7.913361061238693e-98)

# %% [markdown]
# Given the pearson coefficient value is 0.76 and p-value is less than 0.05, we reject the Null Hypothesis, meaning there is a relationship between Nitric oxide concentrations and proportion of non-retail business acres per town

# %% [markdown]
# We can see the relationship in task 4.

# %% [markdown]
# ### Task 9) What is the impact of an additional weighted distance  to the five Boston employment centres on the median value of owner occupied homes? (Regression analysis)

# %% [markdown]
# Hypothesis:
#
# Null hypothesis: There is no relationship between impact of an additional weighted distance to the five Boston employment centres and the median value of owner occupied homes.
#
# Alternative hypothesis: There is relationship between impact of an additional weighted distance to the five Boston employment centres and the median value of owner occupied homes.

# %%
x = boston_df['DIS']
y = boston_df['MEDV']

# %%
x = sm.add_constant(x)

# %%
model = sm.OLS(y,x).fit()
predictions= model.predict(x)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Wed, 22 Mar 2023   Prob (F-statistic):           1.21e-08
# Time:                        16:29:47   Log-Likelihood:                -1823.9
# No. Observations:                 506   AIC:                             3652.
# Df Residuals:                     504   BIC:                             3660.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.3901      0.817     22.499      0.000      16.784      19.996
# ...

# %% [markdown]
# The coef DIS of 1.0916 shows that an additional weighted distance to the 5 empolyment centers in boston increases the median value of owner occupied homes by 1.0916.

# %% [markdown]
# Given the p-value is less than 0.05, we reject the Null Hypothesis, meaning there is relationship between impact of an additional weighted distance to the five Boston employment centres and the median value of owner occupied homes.
